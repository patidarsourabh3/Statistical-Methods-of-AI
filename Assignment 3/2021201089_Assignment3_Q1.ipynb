# %% [markdown]
# # Assignment 3
#
# ## Instructions
# - Run this notebook on ```Google Colab(preferable)```
# - Write your code and analysis in the indicated cells.
# - Ensure that this notebook runs without errors when the cells are run in sequence.
# - Do not attempt to change the contents of other cells.
#
# ## Packages Used
# - Keras [link](https://keras.io/guides/)
#
# ## Submission
# - Rename the notebook to `<roll_number>_Assignment3_Q1.ipynb`.

# %% [markdown]
# ## Question 1

# %% [markdown]
# This question is based on seminal work by Zhang et al. The paper is titled 'Understanding deep learning requires rethinking generalization'. The paper talks about how the traditional methods fail to explain generalization of neural network. They show that a sufficiently parameterized network can easily fit a random labeling of the training data. This fitting cannot be curbed by explicit regularization.

# %% [markdown]
# ## Q) 1.1
# Lets take a hello world dataset for ML algorithm the MNIST!
# This question requires you to train a convolutional neural network.
# Architecture: 4 layers of convolution with 64 filters in each layer. Keep activation map size same using padding.

# %%
from tensorflow import keras   # feel free to use MNIST data from other sources 
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten
from keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import random

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255

x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)

print("Train data shape:", x_train.shape)
print(x_train.shape[0], "train samples")
print(x_test.shape[0], "test samples")
# Out:
# Train data shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %% [markdown]
# #### One-hot-encode your labels here

# %%
print ('label shape: ',np.shape(y_train),np.shape(y_test))
def encode(y):
    return y

y_train = encode(y_train)
y_test = encode(y_test)
print ('label shape: ',np.shape(y_train),np.shape(y_test))
# Out:
# label shape:  (60000,) (10000,)
# label shape:  (60000,) (10000,)

# %% [markdown]
# #### Define the model mentioned above
#     1) Print the number of trainable parameters
#      Use sgd optimizer with softmax at last layer
#      Train the model until convergence (use test data only for model selection and early stopping!)
#     2) Report the train and test accuracy
#     3) Plot the train and test accuracy and loss throughout the training

# %%
#code here
def create_model():
    
    model = Sequential()
    model.add(Conv2D(64, 3, activation='relu', padding='same', input_shape=(28,28,1)))
    model.add(Conv2D(64, 3, activation='relu', padding='same'))
    model.add(Conv2D(64, 3, activation='relu', padding='same'))
    model.add(Conv2D(64, 3, activation='relu', padding='same'))
    model.add(Flatten())
    model.add(Dense(10, activation='softmax'))
    model.compile(loss='sparse_categorical_crossentropy',optimizer='sgd',metrics=['accuracy'])
    return model

# %%
def model_history(model):
    
    training_accuracy = model.history['accuracy']
    testing_accuracy = model.history['val_accuracy']
    training_loss = model.history['loss']
    testing_loss = model.history['val_loss']
    
    return training_accuracy, testing_accuracy, training_loss, testing_loss

# %%
def plot_graphs(epochs,training_accuracy, testing_accuracy, training_loss, testing_loss):
    
    epochs = [x for x in range(1, epochs+1)]
    fig, (ax1, ax2) = plt.subplots(1,2, figsize = (15,5))
    ax1.plot(epochs, training_accuracy, color="red", label="training accuracy")
    ax1.plot(epochs, testing_accuracy,color="blue", label="testing accuracy")
    ax1.set_title("Number of epochs vs Accuracy Plot")
    ax1.set(xlabel = "Number of epochs", ylabel = "Accuracy")
    ax1.legend()
    ax2.plot(epochs, training_loss, color="red", label="training loss")
    ax2.plot(epochs, testing_loss, color="blue", label="testing loss")
    ax2.set_title("Number of epochs vs Loss Plot")
    ax2.set(xlabel = "Number of epochs", ylabel = "Loss")
    ax2.legend()

# %%
def randomize(y_train, noise):
    
    l = len(y_train) * (noise/100)
    for i in range(int(l)):
        x = random.randint(0,9)
        while x==y_train[i] :
            x = random.randint(0,9)
        
        y_train[i] = x
    
    return y_train

# %%
def cnn_model(noise=0):
    
    model = create_model()
    model.summary()
    epochs = 10
    earlystopping = EarlyStopping(monitor='val_accuracy', patience = 2)
    y_train_new = randomize(y_train, noise)
    model = model.fit(x_train, y_train_new, validation_data=(x_test,y_test), epochs = epochs, callbacks=[earlystopping])
    training_accuracy, testing_accuracy, training_loss, testing_loss = model_history(model)
    epochs = len(training_accuracy)
    return epochs, training_accuracy, testing_accuracy, training_loss, testing_loss

# %%
epochs, training_accuracy, testing_accuracy, training_loss, testing_loss = cnn_model()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 64)        640
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 64)        36928
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 64)        36928
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 64)        36928
#
#  flatten (Flatten)           (None, 50176)             0
#
#  dense (Dense)               (None, 10)                501770
#
# =================================================================
# Total params: 613,194
# Trainable params: 613,194
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1875/1875 [==============================] - 43s 18ms/step - loss: 0.3680 - accuracy: 0.8902 - val_loss: 0.1159 - val_accuracy: 0.9650
# Epoch 2/10
# 1875/1875 [==============================] - 34s 18ms/step - loss: 0.0987 - accuracy: 0.9710 - val_loss: 0.0773 - val_accuracy: 0.9752
# Epoch 3/10
# 1875/1875 [==============================] - 34s 18ms/step - loss: 0.0668 - accuracy: 0.9796 - val_loss: 0.0543 - val_accuracy: 0.9824
# Epoch 4/10
# 1875/1875 [==============================] - 34s 18ms/step - loss: 0.0529 - accuracy: 0.9841 - val_loss: 0.0514 - val_accuracy: 0.9840
# Epoch 5/10
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0434 - accuracy: 0.9868 - val_loss: 0.0504 - val_accuracy: 0.9837
# Epoch 6/10
# 1875/1875 [==============================] - 34s 18ms/step - loss: 0.0373 - accuracy: 0.9883 - val_loss: 0.0442 - val_accuracy: 0.9855
# Epoch 7/10
# 1875/1875 [==============================] - 34s 18ms/step - loss: 0.0309 - accuracy: 0.9902 - val_loss: 0.0439 - val_accuracy: 0.9855
# Epoch 8/10
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0254 - accuracy: 0.9918 - val_loss: 0.0451 - val_accuracy: 0.9854

# %%
print("Training Accuracy : ", training_accuracy[epochs-1])
print("Testing Accuracy : ",testing_accuracy[epochs-1])
print("Training Loss : ", training_loss[epochs-1])
print("Testing Loss : ", testing_loss[epochs-1])
# Out:
# Training Accuracy :  0.9917833209037781
# Testing Accuracy :  0.9854000210762024
# Training Loss :  0.02542264387011528
# Testing Loss :  0.04508158564567566

# %%
plot_graphs(epochs, training_accuracy, testing_accuracy, training_loss, testing_loss)

# %% [markdown]
# ## Q) 1.2
# Now lets start adding label noise to the dataset

# %% [markdown]
# 1) Randomize 20% of train labels and repeat Q1 (1,2 & 3)
#
# 2) Randomize 40% of train labels and repeat Q1 (3)
#
# 3) Randomize 60% of train labels and repeat Q1 (3)
#
# 4) Randomize 80% of train labels and repeat Q1 (3)
#
# 5) Randomize 100% of train labels and repeat Q1 (3)

# %% [markdown]
# # Noise = 20%

# %%
epochs, training_accuracy, testing_accuracy, training_loss, testing_loss = cnn_model(20)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 28, 28, 64)        640
#
#  conv2d_5 (Conv2D)           (None, 28, 28, 64)        36928
#
#  conv2d_6 (Conv2D)           (None, 28, 28, 64)        36928
#
#  conv2d_7 (Conv2D)           (None, 28, 28, 64)        36928
#
#  flatten_1 (Flatten)         (None, 50176)             0
#
#  dense_1 (Dense)             (None, 10)                501770
#
# =================================================================
# Total params: 613,194
# Trainable params: 613,194
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1875/1875 [==============================] - 34s 18ms/step - loss: 1.2962 - accuracy: 0.6923 - val_loss: 0.4967 - val_accuracy: 0.9531
# Epoch 2/10
# 1875/1875 [==============================] - 33s 18ms/step - loss: 1.1007 - accuracy: 0.7673 - val_loss: 0.3740 - val_accuracy: 0.9714
# Epoch 3/10
# 1875/1875 [==============================] - 34s 18ms/step - loss: 1.0644 - accuracy: 0.7756 - val_loss: 0.2971 - val_accuracy: 0.9721
# Epoch 4/10
# 1875/1875 [==============================] - 33s 18ms/step - loss: 1.0420 - accuracy: 0.7791 - val_loss: 0.3338 - val_accuracy: 0.9763
# Epoch 5/10
# 1875/1875 [==============================] - 33s 18ms/step - loss: 1.0270 - accuracy: 0.7817 - val_loss: 0.3842 - val_accuracy: 0.9807
# Epoch 6/10
# 1875/1875 [==============================] - 33s 18ms/step - loss: 1.0141 - accuracy: 0.7839 - val_loss: 0.3568 - val_accuracy: 0.9792
# Epoch 7/10
# 1875/1875 [==============================] - 33s 18ms/step - loss: 1.0032 - accuracy: 0.7847 - val_loss: 0.2757 - val_accuracy: 0.9823
# Epoch 8/10
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.9923 - accuracy: 0.7864 - val_loss: 0.3094 - val_accuracy: 0.9802
# Epoch 9/10
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.9826 - accuracy: 0.7869 - val_loss: 0.2914 - val_accuracy: 0.9807

# %%
print("Training Accuracy : ", training_accuracy[epochs-1])
print("Testing Accuracy : ",testing_accuracy[epochs-1])
print("Training Loss : ", training_loss[epochs-1])
print("Testing Loss : ", testing_loss[epochs-1])
# Out:
# Training Accuracy :  0.7868666648864746
# Testing Accuracy :  0.9807000160217285
# Training Loss :  0.9825921058654785
# Testing Loss :  0.291390061378479

# %%
plot_graphs(epochs, training_accuracy, testing_accuracy, training_loss, testing_loss)

# %% [markdown]
# # Noise = 40%

# %%
epochs, training_accuracy, testing_accuracy, training_loss, testing_loss = cnn_model(40)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 28, 28, 64)        640
#
#  conv2d_9 (Conv2D)           (None, 28, 28, 64)        36928
#
#  conv2d_10 (Conv2D)          (None, 28, 28, 64)        36928
#
#  conv2d_11 (Conv2D)          (None, 28, 28, 64)        36928
#
#  flatten_2 (Flatten)         (None, 50176)             0
#
#  dense_2 (Dense)             (None, 10)                501770
#
# =================================================================
# Total params: 613,194
# Trainable params: 613,194
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1875/1875 [==============================] - 34s 18ms/step - loss: 1.7422 - accuracy: 0.5349 - val_loss: 0.6770 - val_accuracy: 0.9474
# Epoch 2/10
# 1875/1875 [==============================] - 33s 17ms/step - loss: 1.6154 - accuracy: 0.5932 - val_loss: 0.6415 - val_accuracy: 0.9634
# Epoch 3/10
# 1875/1875 [==============================] - 33s 18ms/step - loss: 1.5862 - accuracy: 0.6006 - val_loss: 0.6514 - val_accuracy: 0.9675
# Epoch 4/10
# 1875/1875 [==============================] - 33s 18ms/step - loss: 1.5695 - accuracy: 0.6035 - val_loss: 0.6078 - val_accuracy: 0.9709
# Epoch 5/10
# 1875/1875 [==============================] - 33s 17ms/step - loss: 1.5559 - accuracy: 0.6051 - val_loss: 0.5130 - val_accuracy: 0.9728
# Epoch 6/10
# 1875/1875 [==============================] - 33s 17ms/step - loss: 1.5446 - accuracy: 0.6066 - val_loss: 0.6370 - val_accuracy: 0.9766
# Epoch 7/10
# 1875/1875 [==============================] - 33s 17ms/step - loss: 1.5342 - accuracy: 0.6082 - val_loss: 0.6176 - val_accuracy: 0.9752
# Epoch 8/10
# 1875/1875 [==============================] - 33s 17ms/step - loss: 1.5236 - accuracy: 0.6092 - val_loss: 0.6042 - val_accuracy: 0.9763

# %%
plot_graphs(epochs, training_accuracy, testing_accuracy, training_loss, testing_loss)

# %% [markdown]
# # Noise = 60%

# %%
epochs, training_accuracy, testing_accuracy, training_loss, testing_loss = cnn_model(60)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 28, 28, 64)        640
#
#  conv2d_13 (Conv2D)          (None, 28, 28, 64)        36928
#
#  conv2d_14 (Conv2D)          (None, 28, 28, 64)        36928
#
#  conv2d_15 (Conv2D)          (None, 28, 28, 64)        36928
#
#  flatten_3 (Flatten)         (None, 50176)             0
#
#  dense_3 (Dense)             (None, 10)                501770
#
# =================================================================
# Total params: 613,194
# Trainable params: 613,194
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1875/1875 [==============================] - 34s 18ms/step - loss: 2.0772 - accuracy: 0.3615 - val_loss: 1.2381 - val_accuracy: 0.8994
# Epoch 2/10
# 1875/1875 [==============================] - 33s 18ms/step - loss: 2.0016 - accuracy: 0.4113 - val_loss: 1.0414 - val_accuracy: 0.9402
# Epoch 3/10
# 1875/1875 [==============================] - 33s 18ms/step - loss: 1.9801 - accuracy: 0.4199 - val_loss: 1.1260 - val_accuracy: 0.9516
# Epoch 4/10
# 1875/1875 [==============================] - 33s 18ms/step - loss: 1.9685 - accuracy: 0.4233 - val_loss: 1.0048 - val_accuracy: 0.9599
# Epoch 5/10
# 1875/1875 [==============================] - 33s 18ms/step - loss: 1.9592 - accuracy: 0.4250 - val_loss: 1.0324 - val_accuracy: 0.9593
# Epoch 6/10
# 1875/1875 [==============================] - 33s 17ms/step - loss: 1.9505 - accuracy: 0.4265 - val_loss: 0.9688 - val_accuracy: 0.9631
# Epoch 7/10
# 1875/1875 [==============================] - 33s 17ms/step - loss: 1.9433 - accuracy: 0.4286 - val_loss: 0.9753 - val_accuracy: 0.9635
# Epoch 8/10
# 1875/1875 [==============================] - 34s 18ms/step - loss: 1.9359 - accuracy: 0.4293 - val_loss: 0.9249 - val_accuracy: 0.9638
# Epoch 9/10
# 1875/1875 [==============================] - 34s 18ms/step - loss: 1.9289 - accuracy: 0.4296 - val_loss: 0.9793 - val_accuracy: 0.9666
# Epoch 10/10
# 1875/1875 [==============================] - 34s 18ms/step - loss: 1.9214 - accuracy: 0.4304 - val_loss: 0.9580 - val_accuracy: 0.9638

# %%
plot_graphs(epochs, training_accuracy, testing_accuracy, training_loss, testing_loss)

# %% [markdown]
# # Noise = 80%

# %%
epochs, training_accuracy, testing_accuracy, training_loss, testing_loss = cnn_model(80)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_16 (Conv2D)          (None, 28, 28, 64)        640
#
#  conv2d_17 (Conv2D)          (None, 28, 28, 64)        36928
#
#  conv2d_18 (Conv2D)          (None, 28, 28, 64)        36928
#
#  conv2d_19 (Conv2D)          (None, 28, 28, 64)        36928
#
#  flatten_4 (Flatten)         (None, 50176)             0
#
#  dense_4 (Dense)             (None, 10)                501770
#
# =================================================================
# Total params: 613,194
# Trainable params: 613,194
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1875/1875 [==============================] - 34s 18ms/step - loss: 2.2584 - accuracy: 0.2061 - val_loss: 1.7559 - val_accuracy: 0.8476
# Epoch 2/10
# 1875/1875 [==============================] - 33s 18ms/step - loss: 2.2301 - accuracy: 0.2400 - val_loss: 1.6784 - val_accuracy: 0.8835
# Epoch 3/10
# 1875/1875 [==============================] - 33s 18ms/step - loss: 2.2203 - accuracy: 0.2459 - val_loss: 1.5945 - val_accuracy: 0.8915
# Epoch 4/10
# 1875/1875 [==============================] - 34s 18ms/step - loss: 2.2134 - accuracy: 0.2489 - val_loss: 1.5709 - val_accuracy: 0.9242
# Epoch 5/10
# 1875/1875 [==============================] - 33s 18ms/step - loss: 2.2082 - accuracy: 0.2510 - val_loss: 1.5338 - val_accuracy: 0.9186
# Epoch 6/10
# 1875/1875 [==============================] - 34s 18ms/step - loss: 2.2038 - accuracy: 0.2526 - val_loss: 1.4659 - val_accuracy: 0.9252
# Epoch 7/10
# 1875/1875 [==============================] - 33s 18ms/step - loss: 2.1994 - accuracy: 0.2525 - val_loss: 1.5314 - val_accuracy: 0.9292
# Epoch 8/10
# 1875/1875 [==============================] - 34s 18ms/step - loss: 2.1950 - accuracy: 0.2542 - val_loss: 1.5892 - val_accuracy: 0.9290
# Epoch 9/10
# 1875/1875 [==============================] - 34s 18ms/step - loss: 2.1901 - accuracy: 0.2541 - val_loss: 1.4986 - val_accuracy: 0.9188

# %%
plot_graphs(epochs, training_accuracy, testing_accuracy, training_loss, testing_loss)

# %% [markdown]
# # Noise = 100%

# %%
epochs, training_accuracy, testing_accuracy, training_loss, testing_loss = cnn_model(100)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_20 (Conv2D)          (None, 28, 28, 64)        640
#
#  conv2d_21 (Conv2D)          (None, 28, 28, 64)        36928
#
#  conv2d_22 (Conv2D)          (None, 28, 28, 64)        36928
#
#  conv2d_23 (Conv2D)          (None, 28, 28, 64)        36928
#
#  flatten_5 (Flatten)         (None, 50176)             0
#
#  dense_5 (Dense)             (None, 10)                501770
#
# =================================================================
# Total params: 613,194
# Trainable params: 613,194
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1875/1875 [==============================] - 35s 18ms/step - loss: 2.3029 - accuracy: 0.0983 - val_loss: 2.3102 - val_accuracy: 0.0503
# Epoch 2/10
# 1875/1875 [==============================] - 33s 18ms/step - loss: 2.3022 - accuracy: 0.1047 - val_loss: 2.3232 - val_accuracy: 0.0047
# Epoch 3/10
# 1875/1875 [==============================] - 34s 18ms/step - loss: 2.3016 - accuracy: 0.1073 - val_loss: 2.3423 - val_accuracy: 0.0080

# %%
plot_graphs(epochs, training_accuracy, testing_accuracy, training_loss, testing_loss)
